# %%
# download data from gdrive
import gdown
url = 'https://drive.google.com/drive/folders/1kODUESQkgEQn_NRPBu1l5LKmerJC0Ct6?usp=sharing'

# Extract folder ID
folder_id = url.split('/')[-1].split('?')[0]
print(folder_id)
# Out:
# 1kODUESQkgEQn_NRPBu1l5LKmerJC0Ct6

# %%
# Download folder from Google Drive using URL directly
prefix =  "https://drive.google.com/uc?id=1kODUESQkgEQn_NRPBu1l5LKmerJC0Ct6"
gdown.download(prefix+folder_id, 'ct-scan-data-zip')
# Out:
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File c:\Users\ASUS\anaconda3\envs\kidney\Lib\site-packages\gdown\download.py:267, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     266 try:
# --> 267     url = get_url_from_gdrive_confirmation(res.text)
#     268 except FileURLRetrievalError as e:
#
# File c:\Users\ASUS\anaconda3\envs\kidney\Lib\site-packages\gdown\download.py:55, in get_url_from_gdrive_confirmation(contents)
#      54 if not url:
# ---> 55     raise FileURLRetrievalError(
#      56         "Cannot retrieve the public link of the file. "
#      57         "You may need to change the permission to "
#      58         "'Anyone with the link', or have had many accesses. "
#      59         "Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.",
#      60     )
# ...
